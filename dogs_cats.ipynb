# %%
pip install tensorflow
# Out:
# ...
#
# ...

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 import tensorflow as tf
# ----> 2 from keras.preprocessing.image import ImageDataGenerator
#
# ImportError: cannot import name 'ImageDataGenerator' from 'keras.preprocessing.image' (C:\Users\KIIT0001\anaconda3\Lib\site-packages\keras\api\preprocessing\image\__init__.py)

# %%
tf.__version__
# Out:
# '2.17.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 6
#       4 import matplotlib.pyplot as plt
#       5 import os
# ----> 6 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pip install tensorflow numpy matplotlib opencv-python
# Out:
# ...
#
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
dataset/
    ├── dogs/
    └── cats/
# Out:
#   Cell In[28], line 2
#     ├── dogs/
#     ^
# SyntaxError: invalid character '├' (U+251C)

# %%
import numpy as np
import matlplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 2
#       1 import numpy as np
# ----> 2 import matlplotlib.pyplot as plt
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'matlplotlib'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Define the path to the dataset directory
dataset_dir = 'dataset'

# Check the folders inside the dataset
print(os.listdir(dataset_dir))  # Should list ['dogs', 'cats']

# Loop through the folders and load images
for category in ['dogs', 'cats']:
    category_path = os.path.join(dataset_dir, category)
    for img_name in os.listdir(category_path):
        img_path = os.path.join(category_path, img_name)
        img = cv2.imread(img_path)  # Load the image using OpenCV
        img = cv2.resize(img, (150, 150))  # Resize the image to a fixed size (150x150)
        
        # Optionally, visualize the image
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB
        plt.title(f"{category} - {img_name}")
        plt.show()
        break  # Remove this break to load all images
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 9
#       6 dataset_dir = 'dataset'
#       8 # Check the folders inside the dataset
# ----> 9 print(os.listdir(dataset_dir))  # Should list ['dogs', 'cats']
#      11 # Loop through the folders and load images
#      12 for category in ['dogs', 'cats']:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset'

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Define the path to the dataset directory
dataset_dir = 'Datasets'

# Check the folders inside the dataset
print(os.listdir(dataset_dir))  # Should list ['dogs', 'cats']

# Loop through the folders and load images
for category in ['dogs', 'cats']:
    category_path = os.path.join(dataset_dir, category)
    for img_name in os.listdir(category_path):
        img_path = os.path.join(category_path, img_name)
        img = cv2.imread(img_path)  # Load the image using OpenCV
        img = cv2.resize(img, (150, 150))  # Resize the image to a fixed size (150x150)
        
        # Optionally, visualize the image
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB
        plt.title(f"{category} - {img_name}")
        plt.show()
        break  # Remove this break to load all images
# Out:
# ['.ipynb_checkpoints', 'cats', 'dogs']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create an instance of ImageDataGenerator
datagen = ImageDataGenerator(rescale=1./255)  # Normalize pixel values to [0, 1]

# Load images directly from the folder
test_generator = datagen.flow_from_directory(
    'Datasets',
    target_size=(150, 150),  # Resize all images to 150x150
    batch_size=32,
    class_mode='binary'  # Binary classification (dogs vs cats)
)

# Check class labels assigned
print(test_generator.class_indices)  # Should output {'cats': 0, 'dogs': 1}
# Out:
# Found 2000 images belonging to 3 classes.
# {'.ipynb_checkpoints': 0, 'cats': 1, 'dogs': 2}

# %%
import shutil
shutil.rmtree('Datasets/.ipynb_checkpoints')  # Deletes the folder

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create an instance of ImageDataGenerator
datagen = ImageDataGenerator(rescale=1./255)

# Define a function to filter out hidden files or folders (like .ipynb_checkpoints)
def ignore_hidden_files(dir_path):
    return [f for f in os.listdir(dir_path) if not f.startswith('.')]

# Load images, ignoring hidden folders
test_generator = datagen.flow_from_directory(
    'Datasets',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary',
    classes=ignore_hidden_files('Datasets')  # This will ignore folders like .ipynb_checkpoints
)

# Check if the correct number of classes is loaded
print(test_generator.class_indices)
# Out:
# Found 2000 images belonging to 2 classes.
# {'cats': 0, 'dogs': 1}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Build a basic CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')  # For binary classification (dogs vs cats)
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# C:\Users\KIIT0001\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 import tensorflow as tf
# ----> 2 from keras.preprocessing.image import ImageDataGenerator
#
# ImportError: cannot import name 'ImageDataGenerator' from 'keras.preprocessing.image' (C:\Users\KIIT0001\anaconda3\Lib\site-packages\keras\api\preprocessing\image\__init__.py)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.17.0'

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('Datasets/dogs_cats/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 5
#       1 train_datagen = ImageDataGenerator(rescale = 1./255,
#       2                                    shear_range = 0.2,
#       3                                    zoom_range = 0.2,
#       4                                    horizontal_flip = True)
# ----> 5 training_set = train_datagen.flow_from_directory('Datasets/dogs_cats/training_set',
#       6                                                  target_size = (64, 64),
#       7                                                  batch_size = 32,
#       8                                                  class_mode = 'binary')
#
# ...

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('datasets/training_sets',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 4280 images belonging to 3 classes.

# %%
import shutil

# Remove the .ipynb_checkpoints folder from both dogs and cats directories
shutil.rmtree('training_sets/.ipynb_checkpoints', ignore_errors=True)  # Root .ipynb_checkpoints
shutil.rmtree('training_sets/dogs/.ipynb_checkpoints', ignore_errors=True)  # Inside dogs
shutil.rmtree('training_sets/cats/.ipynb_checkpoints', ignore_errors=True)  # Inside cats

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('datasets/training_sets',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 4280 images belonging to 3 classes.

# %%
import shutil
shutil.rmtree('Datasets/'training_sets/.ipynb_checkpoints')
shutil.rmtree('Datasets/training_sets/dogs/.ipynb_checkpoints')
shutil.rmtree('Datasets/training_sets/cats/.ipynb_checkpoints')
# Out:
#   Cell In[36], line 2
#     shutil.rmtree('Datasets/'training_sets/.ipynb_checkpoints')
#                                                              ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
import shutil

# Remove the .ipynb_checkpoints folder if it exists
shutil.rmtree('Datasets/training_sets/.ipynb_checkpoints', ignore_errors=True)
shutil.rmtree('Datasets/training_sets/dogs/.ipynb_checkpoints', ignore_errors=True)
shutil.rmtree('Datasets/training_sets/cats/.ipynb_checkpoints', ignore_errors=True)

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_sets = train_datagen.flow_from_directory('datasets/training_sets',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 4280 images belonging to 2 classes.

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_sets = train_datagen.flow_from_directory('datasets/training_sets',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 4280 images belonging to 2 classes.

# %%
cnn = tf.keras.models.Sequential()

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
cnn.fit(x = training_sets, validation_data = test_set, epochs = 25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 cnn.fit(x = training_sets, validation_data = test_set, epochs = 25)
#
# NameError: name 'test_set' is not defined

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('Datasets/test_sets',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 3 classes.

# %%
import shutil

# Remove the .ipynb_checkpoints folder if it exists
shutil.rmtree('Datasets/test_sets/.ipynb_checkpoints', ignore_errors=True)
shutil.rmtree('Datasets/test_sets/dogs/.ipynb_checkpoints', ignore_errors=True)
shutil.rmtree('Datasets/test_sets/cats/.ipynb_checkpoints', ignore_errors=True)

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_sets = test_datagen.flow_from_directory('Datasets/test_sets',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
cnn.fit(x = training_sets, validation_data = test_sets, epochs = 25)
# Out:
# Epoch 1/25
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 22s 160ms/step - accuracy: 0.6846 - loss: 0.5765 - val_accuracy: 0.7090 - val_loss: 0.5685
# Epoch 2/25
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 22s 156ms/step - accuracy: 0.7168 - loss: 0.5455 - val_accuracy: 0.7040 - val_loss: 0.5773
# Epoch 3/25
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 20s 147ms/step - accuracy: 0.7219 - loss: 0.5542 - val_accuracy: 0.6915 - val_loss: 0.5830
# Epoch 4/25
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - accuracy: 0.7072 - loss: 0.5581 - val_accuracy: 0.7165 - val_loss: 0.5728
# Epoch 5/25
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 25s 178ms/step - accuracy: 0.7260 - loss: 0.5371 - val_accuracy: 0.7275 - val_loss: 0.5492
# Epoch 6/25
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 23s 167ms/step - accuracy: 0.7395 - loss: 0.5149 - val_accuracy: 0.7205 - val_loss: 0.5519
# Epoch 7/25
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 26s 190ms/step - accuracy: 0.7408 - loss: 0.5091 - val_accuracy: 0.7245 - val_loss: 0.5447
# Epoch 8/25
# ...

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Datasets/single_prediction/cat_dog10.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
print(prediction)
# Out:
# dog

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Datasets/single_prediction/cat_dog.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
print(prediction)
# Out:
# dog

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Datasets/single_prediction/cat_dog5.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
print(prediction)
# Out:
# dog

# %%
print(result)
# Out:
# [[1.]]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
test_image = image.load_img('Datasets/single_prediction/cat_dog8.jpg', target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
test_image = test_image / 255.0  # Ensure normalization matches the training data

# %%
from tensorflow.keras.applications import VGG16

vgg_model = VGG16(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
vgg_model.trainable = False  # Freeze the layers

# Add custom layers on top of VGG16
model = Sequential()
model.add(vgg_model)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 28s 0us/step

# %%
print(training_set.class_indices)  # {'cats': 0, 'dogs': 1}
# Out:
# {'cats': 0, 'dogs': 1}

# %%
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Datasets/single_prediction/cat_dog5.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
print(prediction)
# Out:
# dog

# %%
test_image = image.load_img('Datasets/single_prediction/cat_dog6.jpg', target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
test_image = test_image / 255.0  # Ensure normalization matches the training data
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
print(prediction)
# Out:
# cat
